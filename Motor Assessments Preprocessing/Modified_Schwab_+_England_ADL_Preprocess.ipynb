# %%
import pandas as pd

# %%
data = pd.read_csv('Modified_Schwab_+_England_ADL.csv')
data
# Out:
#           REC_ID F_STATUS  PATNO EVENT_ID  PAG_NAME   INFODT  MSEADLG  \
# 0      230954401        S   3403       SC  MODSEADL  06/2010       90
# 1      229763901        S   3402       SC  MODSEADL  06/2010       95
# 2      230939601        S   3400       SC  MODSEADL  06/2010       90
# 3      233166301        S   3400       BL  MODSEADL  07/2010       90
# 4      235635801        S   3406       SC  MODSEADL  07/2010       90
# ...          ...      ...    ...      ...       ...      ...      ...
# 12702  770654001        S   4021      V15  MODSEADL  03/2020       50
# 12703  770907701        S   3206      V16  MODSEADL  03/2020      100
# 12704  771892001        S  60045      V13  MODSEADL  03/2020       80
# 12705  772109701        S  56789      V08  MODSEADL  03/2020      100
# 12706  772117901        S  52274      V10  MODSEADL  03/2020      100
#
#       ORIG_ENTRY            LAST_UPDATE  QUERY SITE_APRV
# 0        07/2010  2020-06-29 14:40:45.0    NaN   07/2010
# ...

# %%
data.columns
# Out:
# Index(['REC_ID', 'F_STATUS', 'PATNO', 'EVENT_ID', 'PAG_NAME', 'INFODT',
#        'MSEADLG', 'ORIG_ENTRY', 'LAST_UPDATE', 'QUERY', 'SITE_APRV'],
#       dtype='object')

# %%
data_new = data.drop(['REC_ID', 'F_STATUS', 'EVENT_ID', 'PAG_NAME', 'INFODT',
       'ORIG_ENTRY', 'LAST_UPDATE', 'QUERY', 'SITE_APRV'], axis=1)
data_new
# Out:
#        PATNO  MSEADLG
# 0       3403       90
# 1       3402       95
# 2       3400       90
# 3       3400       90
# 4       3406       90
# ...      ...      ...
# 12702   4021       50
# 12703   3206      100
# 12704  60045       80
# 12705  56789      100
# 12706  52274      100
#
# [12707 rows x 2 columns]

# %%
data_preprocess = data_new.dropna()
data_preprocess
# Out:
#        PATNO  MSEADLG
# 0       3403       90
# 1       3402       95
# 2       3400       90
# 3       3400       90
# 4       3406       90
# ...      ...      ...
# 12702   4021       50
# 12703   3206      100
# 12704  60045       80
# 12705  56789      100
# 12706  52274      100
#
# [12707 rows x 2 columns]

# %%
data_preprocess.to_csv('Modified_Schwab_+_England_ADL_Preprocess.csv')
