# %%
import pandas as pd

# %%
data = pd.read_csv("PASE_-_Leisure_Time_Activity.csv")
data
# Out:
#           REC_ID F_STATUS  PATNO EVENT_ID PAG_NAME  QUESTNO  ACTVOFT  \
# 0      386746101        S   3443      V04     PASE        3      1.0
# 1      386745901        S   3443      V04     PASE        1      3.0
# 2      386746001        S   3443      V04     PASE        2      1.0
# 3      386746401        S   3443      V04     PASE        6      1.0
# 4      386746201        S   3443      V04     PASE        4      1.0
# ...          ...      ...    ...      ...      ...      ...      ...
# 33647  772121701        S  52274      V10     PASE        6      0.0
# 33648  394436701        S   3506      V06     PASE        3      0.0
# 33649  394436801        S   3506      V06     PASE        4      0.0
# 33650  394436901        S   3506      V06     PASE        5      0.0
# 33651  394437001        S   3506      V06     PASE        6      0.0
#
#                ACTVSPEC  HRDAYFRQ ORIG_ENTRY            LAST_UPDATE QUERY  \
# ...

# %%
data.columns
# Out:
# Index(['REC_ID', 'F_STATUS', 'PATNO', 'EVENT_ID', 'PAG_NAME', 'QUESTNO',
#        'ACTVOFT', 'ACTVSPEC', 'HRDAYFRQ', 'ORIG_ENTRY', 'LAST_UPDATE', 'QUERY',
#        'SITE_APRV'],
#       dtype='object')

# %%
data_new = data.drop(['REC_ID', 'F_STATUS', 'PATNO', 'EVENT_ID', 'PAG_NAME', 'QUESTNO',
                      'ACTVSPEC', 'ORIG_ENTRY', 'LAST_UPDATE', 'QUERY', 'SITE_APRV'], axis=1)
data_new
# Out:
#        ACTVOFT  HRDAYFRQ
# 0          1.0       1.0
# 1          3.0       4.0
# 2          1.0       3.0
# 3          1.0       2.0
# 4          1.0       1.0
# ...        ...       ...
# 33647      0.0       NaN
# 33648      0.0       NaN
# 33649      0.0       NaN
# 33650      0.0       NaN
# 33651      0.0       NaN
#
# [33652 rows x 2 columns]

# %%
data_new.isnull().sum()
# Out:
# ACTVOFT        31
# HRDAYFRQ    14242
# dtype: int64

# %%
data_preprocess = data_new.drop(['HRDAYFRQ'], axis=1).dropna()
data_preprocess
# Out:
#        ACTVOFT
# 0          1.0
# 1          3.0
# 2          1.0
# 3          1.0
# 4          1.0
# ...        ...
# 33647      0.0
# 33648      0.0
# 33649      0.0
# 33650      0.0
# 33651      0.0
#
# [33621 rows x 1 columns]

# %%
data_preprocess.to_csv('PASE_-_Leisure_Time_Activity_Preprocess.csv')
